# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import seaborn as sns
from torch.utils.tensorboard import SummaryWriter
import datetime
from sklearn.metrics import silhouette_score
import plotly.express as px
from sklearn.metrics import silhouette_samples, silhouette_score
# Out:
# C:\Users\User\AppData\Roaming\Python\Python313\site-packages\torch\cuda\__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
pip install gdown
# Out:
# Requirement already satisfied: gdown in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (6.1.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from gdown) (3.25.2)
# Requirement already satisfied: requests[socks] in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in C:\Users\User\AppData\Roaming\Python\Python313\site-packages (from tqdm->gdown) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gdown

# Google Drive file ID from the provided link
file_id = '1Uksjnwy-UEQvqF-0TKbOT6J_s5tXfkMm'
output_path = 'cleaned_data.csv'


gdown.download(f'https://drive.google.com/uc?id={file_id}', output_path, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Uksjnwy-UEQvqF-0TKbOT6J_s5tXfkMm
# To: c:\Users\User\Documents\GitHub\SIAE\notebooks\cleaned_data.csv
# 100%|██████████| 621k/621k [00:01<00:00, 397kB/s]
# 'cleaned_data.csv'

# %%
df = pd.read_csv('cleaned_data.csv', encoding='utf-8')
display(df.head())
# Out:
#   id_diagnostico       sector tamano_empresa  \
# 0      DIAG_0000   Tecnología          Micro
# 1      DIAG_0001   Tecnología         Grande
# 2      DIAG_0002   Tecnología        Pequeña
# 3      DIAG_0003   Tecnología        Pequeña
# 4      DIAG_0004  Manufactura          Micro
#
#    porcentaje_procesos_documentados  presupuesto_anual_tecnología  \
# 0                              0.05                     3000000.0
# 1                              0.81                   261000000.0
# 2                              0.27                    47000000.0
# 3                              0.30                    19000000.0
# 4                              0.08                     6000000.0
#
#                                      respuesta_texto  nivel_madurez  \
# 0  El trabajo es muy empírico, no hay documentaci...        Inicial
# 1  Todo está automatizado, usamos datos para mejo...     Optimizado
# 2  Hay guías básicas pero no siempre se cumplen l...  En Desarrollo
# 3  Hay guías básicas pero no siempre se cumplen l...  En Desarrollo
# 4  Todo es manual, dependemos de una sola persona...        Inicial
#
#                              recomendacion_principal
# 0  Mapear flujos de trabajo de desarrollo y usar ...
# 1  Aplicar MLOps y analítica predictiva para opti...
# 2  Integrar herramientas de tickets con repositor...
# 3  Integrar herramientas de tickets con repositor...
# 4  Estandarizar el registro diario de mermas e in...

# %% [markdown]
# ### Información general del DataFrame

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id_diagnostico                    3000 non-null   object
#  1   sector                            3000 non-null   object
#  2   tamano_empresa                    3000 non-null   object
#  3   porcentaje_procesos_documentados  3000 non-null   float64
#  4   presupuesto_anual_tecnología      3000 non-null   float64
#  5   respuesta_texto                   3000 non-null   object
#  6   nivel_madurez                     3000 non-null   object
#  7   recomendacion_principal           3000 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 187.6+ KB
# None

# %% [markdown]
# ### Estadísticas descriptivas de las columnas numéricas

# %%
display(df.describe(include='all'))
# Out:
#        id_diagnostico      sector tamano_empresa  \
# count            3000        3000           3000
# unique           3000           4              4
# top         DIAG_2999  Tecnología         Grande
# freq                1         797            779
# mean              NaN         NaN            NaN
# std               NaN         NaN            NaN
# min               NaN         NaN            NaN
# 25%               NaN         NaN            NaN
# 50%               NaN         NaN            NaN
# 75%               NaN         NaN            NaN
# max               NaN         NaN            NaN
#
#         porcentaje_procesos_documentados  presupuesto_anual_tecnología  \
# count                        3000.000000                  3.000000e+03
# unique                               NaN                           NaN
# top                                  NaN                           NaN
# freq                                 NaN                           NaN
# mean                            0.444657                  8.352767e+07
# std                             0.279736                  1.096172e+08
# min                             0.000000                  1.000000e+06
# 25%                             0.190000                  1.000000e+07
# 50%                             0.430000                  4.100000e+07
# 75%                             0.670000                  1.102500e+08
# max                             1.000000                  5.000000e+08
#
#                                           respuesta_texto  nivel_madurez  \
# count                                                3000           3000
# unique                                                 32              4
# top     Hay guías básicas pero no siempre se cumplen l...  En Desarrollo
# freq                                                  201            923
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                                   recomendacion_principal
# count                                                3000
# unique                                                 16
# top     Integrar herramientas de tickets con repositor...
# freq                                                  245
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# ### Análisis de columnas categóricas

# %%
categorical_cols = ['sector', 'tamano_empresa', 'nivel_madurez']

for col in categorical_cols:
    print(f"\nValue counts for column: {col}")
    display(df[col].value_counts())
    print(f"\nPercentage distribution for column: {col}")
    display(df[col].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
# Out:
# Value counts for column: sector
# sector
# Tecnología     797
# Manufactura    755
# Retail         724
# Servicios      724
# Name: count, dtype: int64
# Percentage distribution for column: sector
# sector
# Tecnología     26.57%
# Manufactura    25.17%
# Retail         24.13%
# Servicios      24.13%
# Name: proportion, dtype: object
# Value counts for column: tamano_empresa
# tamano_empresa
# Grande     779
# Pequeña    744
# Mediana    741
# Micro      736
# Name: count, dtype: int64
# Percentage distribution for column: tamano_empresa
# tamano_empresa
# Grande     25.97%
# Pequeña     24.8%
# Mediana     24.7%
# Micro      24.53%
# Name: proportion, dtype: object
# Value counts for column: nivel_madurez
# nivel_madurez
# En Desarrollo    923
# Definido         911
# Inicial          783
# Optimizado       383
# Name: count, dtype: int64
# Percentage distribution for column: nivel_madurez
# nivel_madurez
# En Desarrollo    30.77%
# Definido         30.37%
# Inicial           26.1%
# Optimizado       12.77%
# Name: proportion, dtype: object

# %% [markdown]
# ### Visualización de la distribución de columnas categóricas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

categorical_cols = ['sector', 'tamano_empresa', 'nivel_madurez']

plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.countplot(data=df, x='sector', palette='viridis', hue='sector', legend=False)
plt.title('Distribución por Sector')
plt.xticks(rotation=45, ha='right')

plt.subplot(1, 3, 2)
sns.countplot(data=df, x='tamano_empresa', palette='magma', hue='tamano_empresa', legend=False)
plt.title('Distribución por Tamaño de Empresa')
plt.xticks(rotation=45, ha='right')

plt.subplot(1, 3, 3)
sns.countplot(data=df, x='nivel_madurez', palette='plasma', hue='nivel_madurez', legend=False)
plt.title('Distribución por Nivel de Madurez Digital')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de columnas numéricas: Distribución y Outliers

# %%
numerical_cols = ['porcentaje_procesos_documentados', 'presupuesto_anual_tecnología']

plt.figure(figsize=(15, 6))

for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, 2*i + 1)
    # Reemplazamos palette='viridis' por color (ej. '#21918c' o 'teal')
    sns.histplot(df[col], kde=True, bins=30, color='#21918c')
    plt.title(f'Distribución de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')

    plt.subplot(2, 2, 2*i + 2)
    # Reemplazamos palette='magma' por color (ej. '#8c2981' o 'purple')
    sns.boxplot(y=df[col], color='#8c2981')
    plt.title(f'Boxplot de {col}')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relación entre el Nivel de Madurez Digital y las variables numéricas

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='nivel_madurez', y='porcentaje_procesos_documentados', palette='viridis', order=['Inicial', 'En Desarrollo', 'Definido', 'Optimizado'], hue='nivel_madurez', legend=False)
plt.title('Porcentaje de Procesos Documentados por Nivel de Madurez')
plt.xlabel('Nivel de Madurez Digital')
plt.ylabel('Porcentaje de Procesos Documentados')
plt.xticks(rotation=45, ha='right')

plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='nivel_madurez', y='presupuesto_anual_tecnología', palette='magma', order=['Inicial', 'En Desarrollo', 'Definido', 'Optimizado'], hue='nivel_madurez', legend=False)
plt.title('Presupuesto Anual de Tecnología por Nivel de Madurez')
plt.xlabel('Nivel de Madurez Digital')
plt.ylabel('Presupuesto Anual de Tecnología')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relación entre variables categóricas: Sector, Tamaño de Empresa y Nivel de Madurez

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 7))

sns.countplot(data=df, x='sector', hue='nivel_madurez', palette='viridis', ax=axes[0])
axes[0].set_title('Nivel de Madurez Digital por Sector')
axes[0].set_xlabel('Sector')
axes[0].set_ylabel('Número de Empresas')
axes[0].tick_params(axis='x', rotation=45)
axes[0].legend(title='Nivel de Madurez', loc='upper right')

sns.countplot(data=df, x='tamano_empresa', hue='nivel_madurez', palette='magma', ax=axes[1])
axes[1].set_title('Nivel de Madurez Digital por Tamaño de Empresa')
axes[1].set_xlabel('Tamaño de Empresa')
axes[1].set_ylabel('Número de Empresas')
axes[1].tick_params(axis='x', rotation=45)
axes[1].legend(title='Nivel de Madurez', loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matriz de correlación para variables numéricas (si hubiera más de dos)

# %%
numerical_df = df[numerical_cols]

if len(numerical_cols) > 1:
    correlation_matrix = numerical_df.corr()
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Matriz de Correlación de Variables Numéricas')
    plt.show()
else:
    print("Se necesita más de una variable numérica para calcular la matriz de correlación.")
